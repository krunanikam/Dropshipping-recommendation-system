# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#dataset
data = pd.read_csv('final_dataset.csv')
print(data.head())
# Out:
#    Order_ID Order_Priority  Order_Quantity    Sales  Profit  \
# 0      8995           High              35  3389.93  737.94
# 1     43267       Critical              17  1368.14  171.26
# 2     29319            Low              21  4429.69  983.55
# 3     51073  Not Specified              17  2475.08  958.80
# 4     32582  Not Specified              27  2780.88  595.38
#
#                   Region Product_Category  \
# 0  Northwest Territories        Furniture
# 1  Northwest Territories  Office Supplies
# 2               Atlantic       Technology
# 3                   West        Furniture
# 4                   West        Furniture
#
#                                         Product_Name  result
# 0       Luxo Professional Combination Clamp-On Lamps       1
# 1  Honeywell Enviracaire® Portable Air Cleaner fo...       0
# 2                       Canon PC-428 Personal Copier       1
# 3  3M Polarizing Task Lamp with Clamp Arm, Light ...       1
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          365 non-null    int64
#  1   Order_Priority    365 non-null    object
#  2   Order_Quantity    365 non-null    int64
#  3   Sales             365 non-null    float64
#  4   Profit            365 non-null    float64
#  5   Region            365 non-null    object
#  6   Product_Category  365 non-null    object
#  7   Product_Name      365 non-null    object
#  8   result            365 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 25.8+ KB
# None

# %%
print(data.tail())
# Out:
#      Order_ID Order_Priority  Order_Quantity      Sales   Profit   Region  \
# 360     41543            Low              24  1318.8685   172.33  Ontario
# 361     56101  Not Specified              44  5347.1300  1886.41  Ontario
# 362      1059       Critical              22   127.3300     5.30  Ontario
# 363      1059       Critical              24   990.1000   310.22  Ontario
# 364     20003         Medium              39   796.0800    30.29  Ontario
#
#     Product_Category                                       Product_Name  \
# 360       Technology                                       StarTAC 7760
# 361  Office Supplies     GBC Therma-A-Bind 250T Electric Binding System
# 362  Office Supplies  Wilson Jones 14 Line Acrylic Coated Pressboard...
# 363  Office Supplies  Wilson Jones Ledger-Size, Piano-Hinge Binder, ...
# 364       Technology                      Belkin 105-Key Black Keyboard
#
#      result
# 360       0
# 361       1
# 362       0
# 363       0
# 364       0

# %%
df = pd.DataFrame(data)
plt.plot(df['Region'], df['Sales'], color='red', marker='o')
plt.title('Region vs Sales', fontsize=14)
plt.xlabel('Region', fontsize=14)
plt.ylabel('Sales', fontsize=14)
plt.grid(True)
plt.show()

# %%
df = pd.DataFrame(data)
plt.plot(df['Profit'], df['Product_Category'], color='red', marker='o')
plt.title('Profit vs Product_Category', fontsize=14)
plt.xlabel('Profit', fontsize=14)
plt.ylabel('Product_Category', fontsize=14)
plt.grid(True)
plt.show()

# %%
# reading the database
data = pd.read_csv("final_dataset.csv")
 
# Scatter plot with day against tip
plt.scatter(data['Sales'], data['Region'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Sales')
plt.ylabel('Region')
 
plt.show()

# %%
# reading the database
data = pd.read_csv("final_dataset.csv")
 
# Bar chart with day against tip
plt.bar(data['Product_Category'], data['Sales'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('Product_Category')
plt.ylabel('Sales')
 
# Adding the legends
plt.show()

# %%
# reading the database
data = pd.read_csv("final_dataset.csv")
 
# histogram of total_bills
plt.hist(data['Sales'])
 
plt.title("Histogram")
 
# Adding the legends
plt.show()

# %%
pip install seaborn
# Out:
# ...
#
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\solap\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
data = pd.read_csv("final_dataset.csv")
 
sns.lineplot(x='Product_Category', y='Order_Priority', data=data)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
 
data = pd.read_csv("final_dataset.csv")
 
sns.lineplot(x='Region', y='Order_Priority', data=data)
plt.show()
